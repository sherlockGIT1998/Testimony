# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df11 = pd.read_csv('first.csv')
df22 = pd.read_csv('second.csv')
df33 = pd.read_csv('third.csv')
df44 = pd.read_csv('fourth.csv')

# %%
DF = pd.concat([df11,df22,df33,df44])
DF.shape
# Out:
# (32658, 96)

# %%
DF_1 = DF.to_csv('merge.csv')
DF_1

# %%
DF_2 = pd.read_csv('merge.csv')
DF_2
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                          Model  \
# 0                 0           0.0           0             AC Ace (1993-1996)
# 1                 1           1.0           1           AC Aceca (1998-2000)
# 2                 2           2.0           2           AC Aceca (1998-2000)
# 3                 3           3.0           3     AC Cobra MkIII (1965-1967)
# 4                 4           4.0           4  AC Cobra 378 MkIV (1965-1967)
# ...             ...           ...         ...                            ...
# 32653           173           NaN         173                            NaN
# 32654           174           NaN         174                            NaN
# 32655           175           NaN         175                            NaN
# 32656           176           NaN         176                            NaN
# 32657           177           NaN         177                            NaN
#
# ...

# %%
pip install PyMongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

import pymongo

# %%
#  creating server

server = pymongo.MongoClient('mongodb://localhost:27017')
server
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
#  creating Database 

db = server['Platform']
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Platform')

# %%
#  creating Collection 

coll = db['Upgrade1']
coll
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Platform'), 'Upgrade1')

# %%
Data = DF_2.to_dict(orient = 'records')

Data
# Out:
# [{'Unnamed: 0.2': 0,
#   'Unnamed: 0.1': 0.0,
#   'Unnamed: 0': 0,
#   'Model': 'AC Ace (1993-1996)',
#   'Serie': 'Ace',
#   'Company': 'AC',
#   'Body style': 'Convertible (spider/spyder, cabrio/cabriolet, drop/open/soft top)',
#   'Segment': 'Coupe Cabrio',
#   'Production years': '1993, 1994, 1995, 1996',
#   'Cylinders': 'V8',
#   'Displacement': '4942 cm3',
#   'Power(HP)': '260 HP @ 5250 RPM',
#   'Power(BHP)': '256 BHP @ 5250 RPM',
#   'Power(KW)': '191.2 KW @ 5250 RPM',
#   'Torque(lb-ft)': '320 lb-ft @ 3250 RPM',
#   'Torque(Nm)': '434 Nm @ 3250 RPM',
#   'Electrical motor power': nan,
#   'Electrical motor torque': nan,
#   'Fuel System': 'Multipoint Injection Naturally aspirated',
#   'Fuel': 'Gasoline',
#   'Fuel capacity': '21.1 gallons (79.9 L)',
#   'Top Speed': '140 mph (225 km/h)',
#   'Acceleration 0-62 Mph (0-100 kph)': nan,
#   'Drive Type': 'Rear Wheel Drive',
#   'Gearbox': '4-speed automatic',
#   'Front brake': 'Ventilated Discs',
# ...

# %%
db.coll.insert_many(Data)

# %% [markdown]
# ![image.png](attachment:image.png)![image.png](attachment:image.png)
